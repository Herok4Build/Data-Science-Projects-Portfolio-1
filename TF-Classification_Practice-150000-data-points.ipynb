# %% [markdown]
# <h1>Practice With Classification</h1>

# %%
import scipy
# TensorFFlow 2.10.0
import tensorflow as tf

# %%
# Reference:  https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_classification.html#sklearn.datasets.make_classification


def generateData1():
    from sklearn.datasets import make_classification
    generated_data, generated_labels = make_classification(n_samples=150000, n_features=67,n_informative=6,
                                     n_redundant=21,n_classes=4,n_clusters_per_class=3,
                                     class_sep=0.85, random_state=4)
    return generated_data, generated_labels
#Generated a dataset for classification
generated_data, generated_labels=generateData1()

# %%
tf.test.gpu_device_name()
# Out:
# ''

# %% [markdown]
# <h2>Printing the Data</h2>
# <p>First going to print the data to be able to observe some of the features and entries. Then move forward to preprocessing.</p>

# %%
print(generated_data)
# Out:
# [[-2.33361026 -0.60144878  1.08602439 ...  0.78868783  0.07186942
#   -2.52823781]
#  [ 4.48200586  0.63221535  0.14131124 ... -1.84224331  0.74488575
#    0.06351342]
#  [ 1.99279545 -0.56605955  0.67461642 ... -6.4652053   0.7423832
#    0.78304607]
#  ...
#  [ 4.32652487 -1.03521352  1.54943639 ... -2.78466104 -1.12996212
#   -0.81856759]
#  [ 1.46362241  0.59322861  1.63346743 ... -0.61463501 -0.64664391
#   -1.07320272]
#  [ 2.31575017  1.6516817   0.56526007 ... -2.10523538  0.19945917
#    0.02394883]]

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
generated_data_dataframe = pd.DataFrame(data=generated_data)
scalerObject = StandardScaler().fit(generated_data_dataframe)
standardized_generated_dataframe = scalerObject.transform(generated_data_dataframe)
print(generated_data_dataframe)
# Out:
#               0         1         2         3         4         5         6   \
# 0      -2.333610 -0.601449  1.086024  4.782169 -4.875502 -0.713688 -0.435904
# 1       4.482006  0.632215  0.141311 -2.482378  1.430501 -0.225907  0.194697
# 2       1.992795 -0.566060  0.674616  2.753814 -5.786237  0.301980  1.850271
# 3      -0.516511 -0.703934 -0.397685  1.225621 -0.322883  0.060714  0.163667
# 4       1.160782  1.539630 -0.788463 -2.916756  1.389415 -0.538216  0.459161
# ...          ...       ...       ...       ...       ...       ...       ...
# 149995  4.275384 -0.430219 -0.295318 -0.125289 -2.882741 -1.742744 -0.633857
# 149996 -1.481786 -0.124886  0.368768  1.215679 -0.817456 -1.902017 -1.754438
# 149997  4.326525 -1.035214  1.549436 -1.366450  2.206426  0.581431  0.653123
# 149998  1.463622  0.593229  1.633467 -1.958916  2.958400  0.069844 -0.285576
# 149999  2.315750  1.651682  0.565260  0.077944 -0.644020 -1.650009  0.239945
#
#               7         8         9   ...        57        58        59  \
# 0       1.106328 -1.645062  1.042026  ...  1.565108 -0.818719 -1.705340
# 1       1.131455  0.185460 -0.742058  ... -1.015020 -0.737424 -1.878518
# 2       0.377026 -1.028481  1.349787  ...  4.588957  0.543868 -4.064715
# 3       0.271467  1.170365  1.561488  ...  0.015866  0.349037 -2.692936
# 4       1.267309  0.198822  0.880045  ... -1.402756  1.037585  0.639273
# ...          ...       ...       ...  ...       ...       ...       ...
# 149995 -1.895733 -0.534968  1.121300  ...  2.243988 -2.162948 -3.045226
# 149996 -1.433918  0.640566 -1.233820  ...  0.674557  0.236671  0.202936
# 149997  0.073616 -0.992103  1.436835  ... -1.298035  0.451346 -2.924893
# 149998  0.602059 -0.032692 -0.208020  ... -1.254129  0.410982 -0.492384
# 149999  0.162105  1.321994 -1.456707  ...  0.839740 -0.638958 -0.985396
#
#               60        61        62        63        64        65        66
# 0      -0.739624 -0.759932 -0.799492  0.316665  0.788688  0.071869 -2.528238
# 1       1.015771 -1.955026  0.692325  2.358576 -1.842243  0.744886  0.063513
# 2       7.830431 -0.279770  1.043258 -0.025909 -6.465205  0.742383  0.783046
# 3       2.828812 -0.704853  0.276972 -0.587033 -0.829943 -0.011397  0.929050
# 4      -5.034407 -0.792213  1.071879 -0.656475  1.554269 -0.460479 -0.936997
# ...          ...       ...       ...       ...       ...       ...       ...
# 149995  0.158745  1.402545  0.212347  1.286459 -1.910156  0.351886 -0.570434
# 149996  0.162730  1.353015  0.615578 -0.326389  0.475841 -0.331343 -0.851680
# 149997  4.987222  0.434877 -0.222009  0.553823 -2.784661 -1.129962 -0.818568
# 149998  1.956139 -0.892711 -0.159780  1.587562 -0.614635 -0.646644 -1.073203
# 149999  2.782351  1.975465 -2.243257 -0.080990 -2.105235  0.199459  0.023949
#
# [150000 rows x 67 columns]

# %%
print(standardized_generated_dataframe)
# Out:
# [[-1.06784271 -0.60040023  1.08670457 ...  0.47265663  0.07464509
#   -2.53082211]
#  [ 1.60963956  0.63327703  0.14209823 ... -0.77083094  0.74847409
#    0.06508278]
#  [ 0.63176513 -0.56501063  0.67534312 ... -2.95583522  0.74596852
#    0.7857686 ]
#  ...
#  [ 1.54855959 -1.03416959  1.55006417 ... -1.2162568  -1.12863766
#   -0.81841189]
#  [ 0.42388202  0.59428988  1.63408571 ... -0.19061216 -0.64473585
#   -1.07345511]
#  [ 0.75863635  1.65275423  0.56599913 ... -0.89513194  0.20238891
#    0.02545479]]

# %%
#https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.SelectKBest.html#sklearn.feature_selection.SelectKBest
from sklearn.feature_selection import SelectKBest
def featureSelectionOfKBestMeasure(submitted_data, submittedLabels, focused_number_of_features):
    for number in focused_number_of_features:
        transform_by_features = SelectKBest(k=number)
        transform_by_features.fit(submitted_data, submittedLabels)
        print(transform_by_features)
        transformed_data = transform_by_features.fit_transform(submitted_data, submittedLabels)
        print("For ",number," features: \n")
        print(transformed_data)
        print(transform_by_features.pvalues_)
        print(transform_by_features.scores_)
        
#    return transformed_data
possible_feature_numbers = [2,3,4,5,6,7,8,9,10]
featureSelectionOfKBestMeasure(standardized_generated_dataframe, generated_labels,possible_feature_numbers)


#Performing transformation to reduce dimensionality of the data
#transformed_generated_data = featureSelectionOfKBest(standardized_generated_dataframe, generated_labels, 9)
#print(transformed_generated_data)
# Out:
# SelectKBest(k=2)
# For  2  features:
#
# [[ 0.89691338  0.43226255]
#  [ 0.28862799  1.0437158 ]
#  [-0.47665542 -0.57052763]
#  ...
#  [-0.40917417 -0.3238032 ]
#  [-0.5054902  -0.9521048 ]
#  [ 0.11137864  0.43884513]]
# [0.00000000e+000 7.35201401e-001 4.15423290e-002 9.82410443e-256
#  0.00000000e+000 3.85450027e-001 9.51551342e-001 4.34490705e-001
#  1.78195810e-004 7.82109678e-001 8.39061772e-001 0.00000000e+000
#  0.00000000e+000 0.00000000e+000 5.01816671e-001 7.64149705e-001
#  6.27845714e-002 8.26523003e-001 4.89673957e-001 0.00000000e+000
#  0.00000000e+000 1.20472759e-001 0.00000000e+000 0.00000000e+000
#  2.16265997e-001 3.40015298e-001 5.74531509e-001 0.00000000e+000
#  0.00000000e+000 0.00000000e+000 3.43525247e-001 5.12522846e-001
#  0.00000000e+000 4.07411698e-001 5.84171563e-001 4.52697654e-001
#  0.00000000e+000 7.05803459e-001 5.56922678e-001 0.00000000e+000
#  9.10146549e-001 5.66245394e-001 7.97346012e-001 0.00000000e+000
#  7.53032000e-001 0.00000000e+000 0.00000000e+000 8.77172063e-001
#  8.72182099e-001 0.00000000e+000 4.27557321e-001 3.22480087e-001
#  4.67651171e-001 0.00000000e+000 1.24570689e-001 0.00000000e+000
#  0.00000000e+000 0.00000000e+000 4.99593083e-001 0.00000000e+000
#  0.00000000e+000 5.10873304e-001 5.16114093e-001 2.13581549e-001
#  1.10316676e-171 5.28167466e-001 6.49369271e-001]
# [5.34488142e+03 4.24827596e-01 2.74246519e+00 3.95211837e+02
#  6.13708994e+02 1.01344750e+00 1.14666754e-01 9.11317849e-01
#  6.63313130e+00 3.59716641e-01 2.81131567e-01 1.48442261e+03
#  1.27675372e+03 2.52515633e+03 7.85444889e-01 3.84538197e-01
#  2.43507192e+00 2.98486938e-01 8.07118228e-01 5.91570706e+03
#  5.66750335e+03 1.94150070e+00 4.23283203e+03 1.42408863e+03
#  1.48528699e+00 1.11845306e+00 6.63260750e-01 8.16127409e+03
#  5.63595708e+03 3.99728449e+03 1.10992086e+00 7.66666615e-01
#  3.27494368e+03 9.66442452e-01 6.47905601e-01 8.75821155e-01
#  1.15050107e+03 4.66285178e-01 6.91774391e-01 1.91627677e+03
#  1.79810752e-01 6.76601197e-01 3.38714208e-01 6.49583471e+02
#  3.99961785e-01 3.62713197e+03 3.70154643e+03 2.27699124e-01
#  2.34780571e-01 1.74025330e+03 9.25155323e-01 1.16227136e+00
#  8.47519582e-01 1.21601267e+03 1.91581246e+00 3.09585408e+03
#  1.33842142e+03 1.44243189e+03 7.89383283e-01 1.33000921e+03
#  2.02929028e+03 7.69540308e-01 7.60434332e-01 1.49520543e+00
#  2.65205043e+02 7.39751671e-01 5.48127941e-01]
# SelectKBest(k
#  1.79810752e-01 6.76601197e-01 3.38714208e-01 6.49583471e+02
#  3.99961785e-01 3.62713197e+03 3.70154643e+03 2.27699124e-01
#  2.34780571e-01 1.74025330e+03 9.25155323e-01 1.16227136e+00
#  8.47519582e-01 1.21601267e+03 1.91581246e+00 3.09585408e+03
#  1.33842142e+03 1.44243189e+03 7.89383283e-01 1.33000921e+03
#  2.02929028e+03 7.69540308e-01 7.60434332e-01 1.49520543e+00
#  2.65205043e+02 7.39751671e-01 5.48127941e-01]

# %% [markdown]
# Using the <code>SelectKBest</code> method with mutual info classifier metric to select the best eight features.

# %%
from sklearn.feature_selection import mutual_info_classif
def featureSelectionOfKBestResult(submitted_data, submittedLabels, focused_number):
    transform_by_features = SelectKBest(score_func=mutual_info_classif,k=focused_number)
    transform_by_features.fit(X=submitted_data, y=submittedLabels)
    print(transform_by_features)
    transformed_data = transform_by_features.fit_transform(submitted_data, submittedLabels) 
    print(transformed_data)
    return transformed_data

transformed_data = featureSelectionOfKBestResult(standardized_generated_dataframe, generated_labels, 8)
# Out:
# SelectKBest(k=8,
#             score_func=<function mutual_info_classif at 0x000001AFB62FAE60>)
# [[-0.31928642  0.89691338  2.06565293 ...  0.61934678 -1.55208412
#   -0.49887401]
#  [-0.31289571  0.28862799 -0.48670376 ...  1.52384883 -0.73088475
#    0.16674661]
#  [ 0.9192955  -0.47665542  0.09505532 ...  1.62998004  0.99163951
#    2.75076809]
#  ...
#  [ 0.78992099 -0.40917417  0.06108333 ...  1.1176729  -0.11539907
#    1.67266408]
#  [ 1.13306654 -0.5054902  -0.60045338 ... -0.84697956  1.37420793
#    0.52332048]
#  [-0.22210599  0.11137864 -0.67094082 ...  0.89182174 -0.04527037
#    0.83660856]]

# %% [markdown]
# <h2>Exploring the Data</h2>

# %% [markdown]
# Using the covariance matrix, we can observe if the whether the relevant features have a positive or negative relationship with one another.

# %%
from sklearn.covariance import empirical_covariance
print("Calculating the empirical covariance of the data:")
print(empirical_covariance(pd.DataFrame(data=generated_data)))
transformed_origin_generated_data = featureSelectionOfKBestResult(pd.DataFrame(data=generated_data), generated_labels, 8)
print("Calculating the empirical covariance of the transformed data:")
print(empirical_covariance(transformed_origin_generated_data))
print(transformed_origin_generated_data.shape)
# Out:
# Calculating the empirical covariance of the data:
# [[ 6.47973191e+00  2.05287743e-03 -1.45873913e-02 ... -2.67863081e+00
#   -7.59296725e-04 -4.41663763e-03]
#  [ 2.05287743e-03  9.99978709e-01 -4.94539543e-03 ...  4.10637366e-03
#    3.50380845e-05  1.31220934e-03]
#  [-1.45873913e-02 -4.94539543e-03  1.00022617e+00 ...  3.73862600e-03
#    1.38204547e-03 -1.76604390e-03]
#  ...
#  [-2.67863081e+00  4.10637366e-03  3.73862600e-03 ...  4.47647396e+00
#    5.15783989e-03  3.23313067e-03]
#  [-7.59296725e-04  3.50380845e-05  1.38204547e-03 ...  5.15783989e-03
#    9.97589358e-01 -5.04164292e-04]
#  [-4.41663763e-03  1.31220934e-03 -1.76604390e-03 ...  3.23313067e-03
#   -5.04164292e-04  9.96802391e-01]]
# SelectKBest(k=8,
#             score_func=<function mutual_info_classif at 0x000001AFB62FAE60>)
# [[-0.41286433  1.26946652  4.57217398 ...  1.36992848 -4.54508792
#   -0.73962371]
#  [-0.3973812   0.373147   -0.67156225 ...  3.02213209 -2.26854134
#    1.01577118]
#  [ 2.58791364 -0.75451193  0.52364342 ...  3.21599607  2.50667746
#    7.83043095]
#  ...
#  [ 2.27447116 -0.6550771   0.45384904 ...  2.2801931  -0.56227871
#    4.98722236]
#  [ 3.10582806 -0.79700051 -0.90525724 ... -1.30852832  3.56724188
#    1.9561386 ]
#  [-0.17742015  0.11196687 -1.05007148 ...  1.86764334 -0.36786641
#    2.7823514 ]]
# Calculating the empirical covariance of the transformed data:
# [[ 5.8697317   0.27435017  0.83625962 -2.4238694  -0.4083624  -1.69301939
#    4.38794898  3.02625248]
#  [ 0.27435017  2.1712555  -0.55232209  1.53608924 -0.48413001  0.38992916
#   -0.73579869 -1.64883133]
#  [ 0.83625962 -0.55232209  4.22084052 -1.61220357  1.05813925 -0.7000051
#   -2.13453667  0.7555876 ]
#  [-2.4238694   1.53608924 -1.61220357  2.67811383 -0.49257562  1.84499134
#   -2.23631431 -2.19900939]
#  [-0.4083624  -0.48413001  1.05813925 -0.49257562  8.32131711 -2.02114091
#    1.74509179 -4.28634912]
#  [-1.69301939  0.38992916 -0.7000051   1.84499134 -2.02114091  3.33662978
#   -2.32302245  1.29880488]
#  [ 4.38794898 -0.73579869 -2.13453667 -2.23631431  1.74509179 -2.32302245
#    7.68521213  2.01814992]
#  [ 3.02625248 -1.64883133  0.7555876  -2.19900939 -4.28634912  1.29880488
#    2.01814992  6.95498371]]
# (150000, 8)

# %%
#Reference: https://machinelearningmastery.com/tutorial-first-neural-network-python-keras/
# Reference: https://stats.stackexchange.com/questions/362619/why-the-accuracy-of-my-neural-network-is-falling-when-epoch-increases by Tonca
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Input
opimize_by_adam =keras.optimizers.Adam(learning_rate=0.001)
#opimize_by_adam =Adam(learning_rate=0.000023)
def generate_keras_model():
    keras_model = tf.keras.Sequential()
    keras_model.add(tf.keras.Input(shape=(8,),sparse=False))
    keras_model.add(tf.keras.layers.Dense(4,activation="softmax"))
    return keras_model

keras_model_instance = generate_keras_model()

# %%
# Model callbacks for checkpoints
model_callbacks = tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=50)

# %%
set_epochs = 1000
set_metrics = ["binary_accuracy", "categorical_accuracy"]

# %%
keras_model_instance.compile(loss="sparse_categorical_crossentropy", optimizer=opimize_by_adam, metrics=set_metrics,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(transformed_origin_generated_data,generated_labels, test_size=0.3)

# %%
keras_model_instance.fit(x_train,y_train, epochs=set_epochs, batch_size=10000, validation_split=0.2, callbacks = [model_callbacks], verbose = 0)

# %%
keras_model_instance.evaluate(x_test,y_test)
# Out:
# 1407/1407 [==============================] - 2s 1ms/step - loss: 1.2137 - binary_accuracy: 0.2479 - categorical_accuracy: 0.2313
# [1.2137048244476318, 0.24787777662277222, 0.23128889501094818]

# %%
def generate_keras_model_2():
    keras_model = tf.keras.Sequential()
    keras_model.add(tf.keras.Input(shape=(8,),sparse=False))
    keras_model.add(tf.keras.layers.Dense(8,activation="relu"))
    keras_model.add(tf.keras.layers.Dense(4,activation="softmax"))
    return keras_model

keras_model_instance_2 = generate_keras_model_2()

# %%
keras_model_instance_2.compile(loss="sparse_categorical_crossentropy", optimizer=opimize_by_adam, metrics=set_metrics,)

# %%
keras_model_instance_2.fit(x_train,y_train, epochs=set_epochs, batch_size=10000, validation_split=0.2, callbacks = [model_callbacks], verbose = 0)

# %%
keras_model_instance_2.evaluate(x_test,y_test)
# Out:
# 1407/1407 [==============================] - 3s 2ms/step - loss: 0.8513 - binary_accuracy: 0.2545 - categorical_accuracy: 0.2434
# [0.8513441681861877, 0.2544611096382141, 0.2433999925851822]

# %%
def generate_keras_model_3():
    keras_model = tf.keras.Sequential()
    keras_model.add(tf.keras.Input(shape=(8,),sparse=False))
    keras_model.add(tf.keras.layers.Dense(8,activation="relu", kernel_regularizer = "l2"))
    keras_model.add(tf.keras.layers.Dense(16,activation="relu"))
    keras_model.add(tf.keras.layers.Dense(4,activation="softmax"))
    return keras_model

keras_model_instance_3 = generate_keras_model_3()

# %%
keras_model_instance_3.compile(loss="sparse_categorical_crossentropy", optimizer=opimize_by_adam, metrics=set_metrics,)

# %%
keras_model_instance_3.fit(x_train,y_train, epochs=set_epochs, batch_size=10000, validation_split=0.2, callbacks = [model_callbacks], verbose = 0)

# %%
keras_model_instance_3.evaluate(x_test,y_test)
# Out:
# 1407/1407 [==============================] - 3s 2ms/step - loss: 0.5999 - binary_accuracy: 0.2522 - categorical_accuracy: 0.2581
# [0.5999265909194946, 0.2522388994693756, 0.2581111192703247]

# %%
# Reference: https://www.tensorflow.org/tutorials/keras/overfit_and_underfit
# Reduction of overfitting by dropout decreased learning rate over time

def generate_keras_model_4():
    keras_model = tf.keras.Sequential()
    keras_model.add(tf.keras.Input(shape=(8,),sparse=False))
    keras_model.add(tf.keras.layers.Dense(32,activation="relu", kernel_regularizer = "l2"))
    keras_model.add(tf.keras.layers.Dropout(0.25))
    keras_model.add(tf.keras.layers.Dense(32,activation="relu"))
    keras_model.add(tf.keras.layers.Dense(4,activation="softmax"))
    return keras_model

keras_model_instance_4 = generate_keras_model_4()

optim_schedule = keras.optimizers.schedules.InverseTimeDecay(
    0.0012, decay_steps =4000,decay_rate=0.5)
opimize_by_adam_2 = keras.optimizers.Adam(optim_schedule)

# %%
keras_model_instance_4.compile(loss="sparse_categorical_crossentropy", optimizer=opimize_by_adam_2, metrics=set_metrics,)

# %%
keras_model_instance_4.fit(x_train,y_train, epochs=set_epochs, batch_size=10000, validation_split=0.2, callbacks = [model_callbacks], verbose = 0)

# %%
keras_model_instance_4.evaluate(x_test,y_test)
# Out:
# 1407/1407 [==============================] - 4s 3ms/step - loss: 0.4698 - binary_accuracy: 0.2532 - categorical_accuracy: 0.2417
# [0.469806432723999, 0.253211110830307, 0.24168889224529266]

# %%
def generate_keras_model_5():
    keras_model = tf.keras.Sequential()
    keras_model.add(tf.keras.Input(shape=(8,),sparse=False))
    keras_model.add(tf.keras.layers.Dense(64,activation="relu", kernel_regularizer = "l2"))
    keras_model.add(tf.keras.layers.Dropout(0.25))
    keras_model.add(tf.keras.layers.Dense(64,activation="relu", kernel_regularizer = "l2"))
    keras_model.add(tf.keras.layers.Dense(4,activation="softmax"))
    return keras_model

keras_model_instance_5 = generate_keras_model_5()

# %%
keras_model_instance_5.compile(loss="sparse_categorical_crossentropy", optimizer=opimize_by_adam_2, metrics=set_metrics,)

# %%
keras_model_instance_5.fit(x_train,y_train, epochs=set_epochs, batch_size=10000, validation_split=0.2, callbacks = [model_callbacks], verbose = 0)

# %%
keras_model_instance_5.evaluate(x_test,y_test)

# %% [markdown]
# Overall, the 5th Tensorflow model seems to provide the best overall performance.

# %%
def generate_keras_model_6():
    keras_model = tf.keras.Sequential()
    keras_model.add(tf.keras.Input(shape=(8,),sparse=False))
    keras_model.add(tf.keras.layers.Dense(64,activation="relu", kernel_regularizer = "l2"))
    keras_model.add(tf.keras.layers.Dropout(0.11))
    keras_model.add(tf.keras.layers.Dense(64,activation="relu", kernel_regularizer = "l2"))
    keras_model.add(tf.keras.layers.Dense(32,activation="relu", kernel_regularizer = "l2"))
    keras_model.add(tf.keras.layers.Dense(4,activation="softmax"))
    return keras_model

keras_model_instance_6 = generate_keras_model_6()

# %%
keras_model_instance_6.compile(loss="sparse_categorical_crossentropy", optimizer=opimize_by_adam_2, metrics=set_metrics,)

# %%
keras_model_instance_6.fit(x_train,y_train, epochs=set_epochs, batch_size=10000, validation_split=0.2, callbacks = [model_callbacks], verbose = 0)

# %%
keras_model_instance_6.evaluate(x_test,y_test)

# %% [markdown]
# The sixth tensorflow model does offer some competition to the fifth tensorflow model. Not necessarily better but some competition.

# %%
def generate_keras_model_7():
    keras_model = tf.keras.Sequential()
    keras_model.add(tf.keras.Input(shape=(8,),sparse=False))
    keras_model.add(tf.keras.layers.Dense(6,activation="relu", kernel_regularizer = "l2"))
    keras_model.add(tf.keras.layers.Dropout(0.05))
    keras_model.add(tf.keras.layers.Dense(6,activation="relu", kernel_regularizer = "l2"))
    keras_model.add(tf.keras.layers.Dense(6,activation="gelu"))
    tf.keras.layers.LeakyReLU(alpha=0.1)
    keras_model.add(tf.keras.layers.Dense(6,activation="relu"))
    keras_model.add(tf.keras.layers.Dense(4,activation="softmax"))
    return keras_model

keras_model_instance_7 = generate_keras_model_7()

# %%
keras_model_instance_7.compile(loss="sparse_categorical_crossentropy", optimizer=opimize_by_adam_2, metrics=set_metrics,)

# %%
keras_model_instance_7.fit(x_train,y_train, epochs=set_epochs, batch_size=10000, validation_split=0.2, callbacks = [model_callbacks], verbose = 0)

# %%
keras_model_instance_7.evaluate(x_test,y_test)

# %% [markdown]
# There seems to be some competition from the 7th model.

# %%
def generate_keras_model_8():
    keras_model = tf.keras.Sequential()
    keras_model.add(tf.keras.Input(shape=(8,),sparse=False))
    keras_model.add(tf.keras.layers.Dense(6,activation="elu"))
    keras_model.add(tf.keras.layers.Dropout(0.15))
    keras_model.add(tf.keras.layers.Dense(6,activation="relu", kernel_regularizer = "l2"))
    keras_model.add(tf.keras.layers.Dense(6,activation="gelu"))
    tf.keras.layers.LeakyReLU(alpha=0.1)
    keras_model.add(tf.keras.layers.Dense(6,activation="relu"))
    keras_model.add(tf.keras.layers.Dense(4,activation="softmax"))
    return keras_model

keras_model_instance_8 = generate_keras_model_8()

# %%
keras_model_instance_8.compile(loss="sparse_categorical_crossentropy", optimizer=opimize_by_adam_2, metrics=set_metrics,)

# %%
keras_model_instance_8.fit(x_train,y_train, epochs=set_epochs, batch_size=10000, validation_split=0.2, callbacks = [model_callbacks], verbose = 0)

# %%
keras_model_instance_8.evaluate(x_test,y_test)

# %%
x_train.shape

# %%
x_test.shape
